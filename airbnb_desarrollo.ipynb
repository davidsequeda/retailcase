# %% [markdown]
# ## caracterización de alojamiento en Ámsterdam
#
# Qué es caracterizar? establecer unas características que clasifique o agrupe los alojameintos en esta ciudad
#
# las hipótesis deben se rvalidadas mediante el uso del anális exploratorio
# El análisis exploratoria de variables implica calculos de frrecuencia, medidas de tendencia central, medidas de localización de conjunto de datos, medidas de variabilidad (variabilidad, disperción,posición)
#
# Hipótesis:¿Entre que puntajes está el 53% de las calificaciones de revisión más bajas de la plataforma?
#
#
#
#
#
#
#
# El 53% de los puntajes de revisión de las publicaciones en la plataforma de Airbnb están entre 20 y 96 puntos.
#
# El precio promedio de alquiler de un inmueble que esté por encima del 78% de los precios de la ciudad es de 300 euros.
#
# El 20% de los inmuebles de la ciudad se están alquilando por debajo de la media de la ciudad de Ámsterdam.
#
# Alberto afirma haber alquilado un inmueble a una desviación estándar por encima del promedio en la plataforma de Airbnb por un valor de 130 euros.

# %%
#importar las librerias necesarias según el análisis que se vaya a realizar
#librería para comnados de sistema

import os
#librería para manejo de datos
import pandas as pd

# Definiendo las columnas a leer
#cargar datos
bnb_data=pd.read_csv('listings_m.csv',sep=";", encoding="latin-1")
# Out:
# C:\Users\ROSAR\AppData\Local\Temp\ipykernel_18448\38391773.py:10: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   bnb_data=pd.read_csv('listings_m.csv',sep=";", encoding="latin-1")

# %%
#lectura de datos
#visualizar los primeros registros

bnb_data.head()
# Out:
#       id                         listing_url    scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  2,02104E+13   12/04/2021
# 1  20168  https://www.airbnb.com/rooms/20168  2,02104E+13   12/04/2021
# 2  25428  https://www.airbnb.com/rooms/25428  2,02104E+13   11/04/2021
# 3  27886  https://www.airbnb.com/rooms/27886  2,02104E+13   11/04/2021
# 4  28871  https://www.airbnb.com/rooms/28871  2,02104E+13   13/04/2021
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1       Studio with private bathroom in the centre 1
# 2  Lovely, 1 bed apt in Ctr (w.lift) -3/20-6/20(f...
# 3  Romantic, stylish B&B houseboat in canal district
# 4                            Comfortable double room
#
#                                          description  \
# 0  Quiet Garden View Room & Super Fast WiFi<br />...
# 1  17th century Dutch townhouse in the heart of t...
# ...

# %%
bnb_data.dtypes
# Out:
# id                                                int64
# listing_url                                      object
# scrape_id                                        object
# last_scraped                                     object
# name                                             object
#                                                  ...
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# Length: 74, dtype: object

# %%
frec_data=bnb_data['review_scores_rating'].value_counts().reset_index()
frec_data.head(20)
# Out:
#     review_scores_rating  count
# 0                  100.0   4582
# 1                   98.0   1557
# 2                   97.0   1274
# 3                   96.0   1162
# 4                   95.0    956
# 5                   99.0    931
# 6                   93.0    916
# 7                   90.0    650
# 8                   94.0    616
# 9                   80.0    398
# 10                  92.0    397
# 11                  91.0    382
# 12                  87.0    230
# 13                  89.0    195
# 14                  88.0    183
# 15                  85.0    130
# 16                  86.0     95
# 17                  60.0     92
# 18                  84.0     88
# 19                  83.0     73

# %%
bnb_data["price"]. quantile([0.66,0.78,0.79,.8,.81,.82,.83,.84,.85,.86,.87,.88,.89,.90,.91,.92,.93,.94,.95,.96,.97,.98,.99,1]).reset_index()
# Out:
#     index    price
# 0    0.66   153.00
# 1    0.78   195.00
# 2    0.79   199.00
# 3    0.80   200.00
# 4    0.81   200.00
# 5    0.82   200.00
# 6    0.83   206.00
# 7    0.84   215.00
# 8    0.85   220.00
# 9    0.86   225.00
# 10   0.87   235.00
# 11   0.88   248.00
# 12   0.89   250.00
# 13   0.90   250.00
# 14   0.91   260.00
# 15   0.92   275.00
# 16   0.93   294.00
# 17   0.94   300.00
# 18   0.95   320.00
# 19   0.96   350.00
# 20   0.97   392.12
# 21   0.98   447.52
# 22   0.99   524.76
# 23   1.00  8000.00

# %%
bnb_data["price"]. mean()
# Out:
# 154.4958765778401

# %%
bnb_data["price"]. std()
# Out:
# 154.16256588595425

# %%
bnb_data['review_scores_rating'].quantile([0.45,.53])
# Out:
# 0.45    96.0
# 0.53    97.0
# Name: review_scores_rating, dtype: float64
